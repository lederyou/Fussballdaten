# %%
import pandas as pd
import re
import math
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle
from scipy.stats import chi2
from scipy.stats import chi2_contingency

# %%
file_path = '/Users/youri/VSC Data/Data Analytics/Fussballdaten/SerieA/Serie_A_Bereinigt.csv'
df = pd.read_csv(file_path)

# Anzeigen der ersten paar Zeilen der Tabelle zur Überprüfung
df.head(10)
# Out:
#     League     Saison  Spieltag      hometeam_raw    awayteam_raw  \
# 0  Serie A  2014/2015         1  AC Chievo Verona  Juventus Turin
# 1  Serie A  2014/2015         1            AS Rom      AC Florenz
# 2  Serie A  2014/2015         1            AS Rom      AC Florenz
# 3  Serie A  2014/2015         1        AC Mailand       Lazio Rom
# 4  Serie A  2014/2015         1        AC Mailand       Lazio Rom
# 5  Serie A  2014/2015         1        AC Mailand       Lazio Rom
# 6  Serie A  2014/2015         1        AC Mailand       Lazio Rom
# 7  Serie A  2014/2015         1         AC Cesena        FC Parma
# 8  Serie A  2014/2015         1     FC Genua 1893      SSC Neapel
# 9  Serie A  2014/2015         1     FC Genua 1893      SSC Neapel
#
#   final_score_raw goal_raw  goal_time_raw  extratime_raw
# 0             0:1      0:1            NaN              0
# 1             2:0      2:0            NaN              0
# 2             2:0      1:0            NaN              0
# 3             1:0      3:1            NaN              0
# 4             1:0      3:0            NaN              0
# 5             1:0      2:0            NaN              0
# 6             1:0      1:0            NaN              0
# 7             1:0      1:0            NaN              0
# 8             1:2      1:2            NaN              0
# 9             1:2      1:1            NaN              0
