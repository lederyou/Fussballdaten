# %% [markdown]
# # Bundesliga bereinigen

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import re

# %% [markdown]
# ## Laden der Excel-Datei

# %%
file_path = '/Users/youri/VSC Data/Data Analytics/Fussballdaten/1Bundesliga_alle_tore_zeiten_15_23.xlsx'
df = pd.read_excel(file_path)

# Anzeigen der ersten paar Zeilen der Tabelle zur Überprüfung
df.head()
# Out:
#                                         matchday_raw   hometeam_raw  \
# 0  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 1  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 2  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 3  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 4  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
#
#       awayteam_raw final_score_raw goal_raw goal_time_raw extratime_raw
# 0  1899 Hoffenheim             NaN      1:1           NaN           NaN
# 1  1899 Hoffenheim             NaN      NaN           NaN           NaN
# 2  1899 Hoffenheim             NaN      NaN           NaN           NaN
# 3  1899 Hoffenheim             NaN      0:1           NaN           NaN
# 4  1899 Hoffenheim             NaN      NaN           80'            no

# %%
def clean_data(df):
    """
    Bereinigt den DataFrame, indem Zeilen entfernt werden, in denen alle angegebenen Spalten leer sind.

    :param df: Der zu bereinigende DataFrame.
    :return: Der bereinigte DataFrame.
    """

    columns_to_check = ['final_score_raw', 'goal_raw', 'goal_time_raw', 'extratime_raw']
    # Entfernen von Zeilen, in denen alle spezifizierten Spalten leer sind
    df_cleaned = df.dropna(subset=columns_to_check, how='all')
    return df_cleaned

# Beispiel für die Verwendung der Funktion
df_cleaned = clean_data(df)
df_cleaned.head()
# Out:
#                                          matchday_raw   hometeam_raw  \
# 0   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 3   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 4   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 5   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 6   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 8   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 10  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 15  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 16  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 17  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
#
#         awayteam_raw final_score_raw goal_raw goal_time_raw extratime_raw
# 0    1899 Hoffenheim             NaN      1:1           NaN           NaN
# 3    1899 Hoffenheim             NaN      0:1           NaN           NaN
# 4    1899 Hoffenheim             NaN      NaN           80'            no
# 5    1899 Hoffenheim             NaN      NaN           75'            no
# 6   Bayer Leverkusen             NaN      3:0           NaN           NaN
# 8   Bayer Leverkusen             NaN      2:0           NaN           NaN
# 10  Bayer Leverkusen             NaN      1:0           NaN           NaN
# 15  Bayer Leverkusen             NaN      NaN           86'            no
# 16  Bayer Leverkusen             NaN      NaN           34'            no
# 17  Bayer Leverkusen             NaN      NaN           19'            no

# %%
# Funktionen zur Extraktion von Spieltag und Saison
def extract_spieltag(text):
    match = re.search(r'(\d+)\. Spieltag', text)
    return match.group(1) if match else None

def extract_saison(text):
    match = re.search(r'\b(\d{4}/\d{4})\b', text)
    return match.group(1) if match else None

# Test der Funktionen mit einem Beispieltext
example_text = "Bundesliga 2022/2023 - 34. Spieltag - Sa., 27...."

test_spieltag = extract_spieltag(example_text)
test_saison = extract_saison(example_text)

test_spieltag, test_saison
# Out:
# ('34', '2022/2023')

# %%
# Erstellen eines DataFrame
df_example = pd.DataFrame(df_cleaned)

# Anwenden der Funktionen zur Erstellung der neuen Spalten
df_example['League'] = 'Bundesliga'
df_example['Spieltag'] = df_example['matchday_raw'].apply(extract_spieltag)
df_example['Saison'] = df_example['matchday_raw'].apply(extract_saison)

# Anzeigen der ersten paar Zeilen des aktualisierten DataFrame
df_example.head()
# Out:
#                                          matchday_raw   hometeam_raw  \
# 0   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 3   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 4   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 5   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....  VfB Stuttgart
# 6   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 8   Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 10  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 15  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 16  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 17  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
# 18  Bundesliga 2022/2023 - 34. Spieltag - Sa., 27....     VfL Bochum
#
#         awayteam_raw final_score_raw goal_raw goal_time_raw extratime_raw  \
# 0    1899 Hoffenheim             NaN      1:1           NaN           NaN
# 3    1899 Hoffenheim             NaN      0:1           NaN           NaN
# 4    1899 Hoffenheim             NaN      NaN           80'            no
# 5    1899 Hoffenheim             NaN      NaN           75'            no
# 6   Bayer Leverkusen             NaN      3:0           NaN           NaN
# 8   Bayer Leverkusen             NaN      2:0           NaN           NaN
# 10  Bayer Leverkusen             NaN      1:0           NaN           NaN
# 15  Bayer Leverkusen             NaN      NaN           86'            no
# 16  Bayer Leverkusen             NaN      NaN           34'            no
# 17  Bayer Leverkusen             NaN      NaN           19'            no
# 18  Bayer Leverkusen             NaN      NaN            8'            no
#
#         League Spieltag     Saison
# 0   Bundesliga       34  2022/2023
# 3   Bundesliga       34  2022/2023
# 4   Bundesliga       34  2022/2023
# 5   Bundesliga       34  2022/2023
# 6   Bundesliga       34  2022/2023
# 8   Bundesliga       34  2022/2023
# 10  Bundesliga       34  2022/2023
# 15  Bundesliga       34  2022/2023
# 16  Bundesliga       34  2022/2023
# 17  Bundesliga       34  2022/2023
# 18  Bundesliga       34  2022/2023

# %%
def merge_goal_times(df):
    """
    Fügt die Torzeiten in die gleiche Zeile wie die Tore ein, ohne Daten zu löschen, wenn es mehr Torzeiten als Tore gibt.

    :param df: Der zu bearbeitende DataFrame.
    :return: Der bearbeitete DataFrame.
    """
    # Gruppieren der Daten nach Spielen
    grouped = df.groupby(['matchday_raw', 'hometeam_raw', 'awayteam_raw'])

    # Listen zur Speicherung der bearbeiteten Daten
    merged_data = []

    # Durchlaufen jeder Gruppe (jedes Spiels)
    for _, group in grouped:
        # Extrahieren der Tore und Torzeiten
        goals = group['goal_raw'].dropna().tolist()
        times = group['goal_time_raw'].dropna().tolist()

        # Sicherstellen, dass die Länge von Toren und Zeiten gleich ist
        max_length = max(len(goals), len(times))
        goals += [None] * (max_length - len(goals))  # Füllen mit None, falls notwendig
        times += [None] * (max_length - len(times))  # Füllen mit None, falls notwendig

        # Erstellen einer neuen DataFrame für das aktuelle Spiel
        game_data = group.iloc[:max_length].copy()
        game_data['goal_raw'] = goals
        game_data['goal_time_raw'] = times

        # Hinzufügen der bearbeiteten Daten zur Liste
        merged_data.append(game_data)

    # Zusammenführen aller bearbeiteten Spiele zurück in einen DataFrame
    return pd.concat(merged_data)

# Beispiel für die Verwendung der Funktion
# df_example = pd.DataFrame(...)  # Ersetzen Sie dies durch Ihren DataFrame
df_cleaned = merge_goal_times(df_example)
df_cleaned.head(10)
# Out:
#                                             matchday_raw         hometeam_raw  \
# 26683  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...    FC Bayern München
# 26684  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...    FC Bayern München
# 26685  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...    FC Bayern München
# 26652  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...      1899 Hoffenheim
# 26654  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...      1899 Hoffenheim
# 26679  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...  Eintracht Frankfurt
# 26658  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...          Hannover 96
# 26660  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...          Hannover 96
# 26663  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...          Hannover 96
# 26668  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...           Hertha BSC
#
#            awayteam_raw final_score_raw goal_raw goal_time_raw extratime_raw  \
# 26683     VfL Wolfsburg             2:1      2:1           52'           NaN
# 26684     VfL Wolfsburg             2:1      2:0           47'           NaN
# 26685     VfL Wolfsburg             2:1      1:0           38'           NaN
# 26652       FC Augsburg             NaN      2:0           35'           NaN
# 26654       FC Augsburg             NaN      1:0           33'           NaN
# 26679       SC Freiburg             NaN      1:0           15'           NaN
# 26658     FC Schalke 04             NaN      2:1           70'           NaN
# 26660     FC Schalke 04             NaN      1:1           67'           NaN
# 26663     FC Schalke 04             NaN      0:1           47'           NaN
# 26668  SV Werder Bremen             NaN      2:2           55'           NaN
#
#            League Spieltag     Saison
# 26683  Bundesliga        1  2014/2015
# 26684  Bundesliga        1  2014/2015
# 26685  Bundesliga        1  2014/2015
# 26652  Bundesliga        1  2014/2015
# 26654  Bundesliga        1  2014/2015
# 26679  Bundesliga        1  2014/2015
# 26658  Bundesliga        1  2014/2015
# 26660  Bundesliga        1  2014/2015
# 26663  Bundesliga        1  2014/2015
# 26668  Bundesliga        1  2014/2015

# %%
def merge_goal_times(df):
    """
    Fügt die Torzeiten in die gleiche Zeile wie die Tore ein und übernimmt die Daten aus der Spalte 'extratime_raw',
    ohne Daten zu löschen, wenn es mehr Torzeiten als Tore gibt.

    :param df: Der zu bearbeitende DataFrame.
    :return: Der bearbeitete DataFrame.
    """
    # Gruppieren der Daten nach Spielen
    grouped = df.groupby(['matchday_raw', 'hometeam_raw', 'awayteam_raw'])

    # Listen zur Speicherung der bearbeiteten Daten
    merged_data = []

    # Durchlaufen jeder Gruppe (jedes Spiels)
    for _, group in grouped:
        # Extrahieren der Tore, Torzeiten und Extrazeiten
        goals = group['goal_raw'].dropna().tolist()
        times = group['goal_time_raw'].dropna().tolist()
        extratimes = group['extratime_raw'].dropna().tolist()

        # Sicherstellen, dass die Länge der Listen gleich ist
        max_length = max(len(goals), len(times), len(extratimes))
        goals += [None] * (max_length - len(goals))
        times += [None] * (max_length - len(times))
        extratimes += [None] * (max_length - len(extratimes))

        # Erstellen einer neuen DataFrame für das aktuelle Spiel
        game_data = group.iloc[:max_length].copy()
        game_data['goal_raw'] = goals
        game_data['goal_time_raw'] = times
        game_data['extratime_raw'] = extratimes

        # Hinzufügen der bearbeiteten Daten zur Liste
        merged_data.append(game_data)

    # Zusammenführen aller bearbeiteten Spiele zurück in einen DataFrame
    return pd.concat(merged_data)

# Beispiel für die Verwendung der Funktion
# df_example = pd.DataFrame(...)  # Ersetzen Sie dies durch Ihren DataFrame
df_cleaned = merge_goal_times(df_example)
df_cleaned.head()
# Out:
#                                             matchday_raw  \
# 26683  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...
# 26684  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...
# 26685  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...
# 26652  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26654  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26679  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26658  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26660  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26663  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26668  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26670  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26671  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26673  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26647  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26649  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26635  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26636  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26638  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26641  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26628  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
#
#                    hometeam_raw      awayteam_raw final_score_raw goal_raw  \
# 26683         FC Bayern München     VfL Wolfsburg             2:1      2:1
# 26684         FC Bayern München     VfL Wolfsburg             2:1      2:0
# 26685         FC Bayern München     VfL Wolfsburg             2:1      1:0
# 26652           1899 Hoffenheim       FC Augsburg             NaN      2:0
# 26654           1899 Hoffenheim       FC Augsburg             NaN      1:0
# 26679       Eintracht Frankfurt       SC Freiburg             NaN      1:0
# 26658               Hannover 96     FC Schalke 04             NaN      2:1
# 26660               Hannover 96     FC Schalke 04             NaN      1:1
# 26663               Hannover 96     FC Schalke 04             NaN      0:1
# 26668                Hertha BSC  SV Werder Bremen             NaN      2:2
# 26670                Hertha BSC  SV Werder Bremen             NaN      2:1
# 26671                Hertha BSC  SV Werder Bremen             NaN      2:0
# 26673                Hertha BSC  SV Werder Bremen             NaN      1:0
# 26647         Borussia Dortmund  Bayer Leverkusen             NaN      0:2
# 26649         Borussia Dortmund  Bayer Leverkusen             NaN      0:1
# 26635           SC Paderborn 07   1. FSV Mainz 05             NaN      2:2
# 26636           SC Paderborn 07   1. FSV Mainz 05             NaN      2:1
# 26638           SC Paderborn 07   1. FSV Mainz 05             NaN      1:1
# 26641           SC Paderborn 07   1. FSV Mainz 05             NaN      0:1
# 26628  Borussia Mönchengladbach     VfB Stuttgart             NaN      1:1
#
#       goal_time_raw extratime_raw      League Spieltag     Saison
# 26683           52'            no  Bundesliga        1  2014/2015
# 26684           47'            no  Bundesliga        1  2014/2015
# 26685           38'            no  Bundesliga        1  2014/2015
# 26652           35'            no  Bundesliga        1  2014/2015
# 26654           33'            no  Bundesliga        1  2014/2015
# 26679           15'            no  Bundesliga        1  2014/2015
# 26658           70'            no  Bundesliga        1  2014/2015
# 26660           67'            no  Bundesliga        1  2014/2015
# 26663           47'            no  Bundesliga        1  2014/2015
# 26668           55'            no  Bundesliga        1  2014/2015
# 26670           53'            no  Bundesliga        1  2014/2015
# 26671           47'            no  Bundesliga        1  2014/2015
# 26673           16'            no  Bundesliga        1  2014/2015
# 26647           90'            no  Bundesliga        1  2014/2015
# 26649            1'            no  Bundesliga        1  2014/2015
# 26635           90'            no  Bundesliga        1  2014/2015
# 26636           87'            no  Bundesliga        1  2014/2015
# 26638           38'            no  Bundesliga        1  2014/2015
# 26641           34'            no  Bundesliga        1  2014/2015
# 26628           90'            no  Bundesliga        1  2014/2015

# %%
def update_final_score(df):
    """
    Aktualisiert den final_score_raw basierend auf dem spätesten Tor in jedem Spiel.
    Spiele ohne Tore erhalten den final_score_raw '0:0'.

    :param df: Der zu bearbeitende DataFrame.
    :return: Der bearbeitete DataFrame mit aktualisiertem final_score_raw.
    """
    # Gruppieren der Daten nach Spielen
    grouped = df.groupby(['matchday_raw', 'hometeam_raw', 'awayteam_raw'])

    # Liste zur Speicherung der bearbeiteten Daten
    updated_data = []

    # Durchlaufen jeder Gruppe (jedes Spiels)
    for _, group in grouped:
        # Extrahieren der Tore und Torzeiten
        goals = group['goal_raw'].dropna().tolist()
        times = group['goal_time_raw'].dropna().tolist()

        # Ermitteln des finalen Spielstands
        if goals:
            # Das letzte Tor (basierend auf der Zeit) ist der finale Spielstand
            final_score = sorted(zip(times, goals))[-1][1]
        else:
            # Keine Tore gefallen, daher '0:0'
            final_score = '0:0'

        # Aktualisieren des final_score_raw für das aktuelle Spiel
        game_data = group.copy()
        game_data['final_score_raw'] = final_score

        # Hinzufügen der bearbeiteten Daten zur Liste
        updated_data.append(game_data)

    # Zusammenführen aller bearbeiteten Spiele zurück in einen DataFrame
    return pd.concat(updated_data)

# Anwenden der Funktion auf Ihren DataFrame
df_updated = update_final_score(df_cleaned)
df_updated.head()
# Out:
#                                             matchday_raw  \
# 26683  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...
# 26684  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...
# 26685  Bundesliga 2014/2015 - 1. Spieltag - Fr., 22.0...
# 26652  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26654  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26679  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26658  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26660  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26663  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26668  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26670  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26671  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26673  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26647  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26649  Bundesliga 2014/2015 - 1. Spieltag - Sa., 23.0...
# 26635  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26636  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26638  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26641  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
# 26628  Bundesliga 2014/2015 - 1. Spieltag - So., 24.0...
#
#                    hometeam_raw      awayteam_raw final_score_raw goal_raw  \
# 26683         FC Bayern München     VfL Wolfsburg             2:1      2:1
# 26684         FC Bayern München     VfL Wolfsburg             2:1      2:0
# 26685         FC Bayern München     VfL Wolfsburg             2:1      1:0
# 26652           1899 Hoffenheim       FC Augsburg             2:0      2:0
# 26654           1899 Hoffenheim       FC Augsburg             2:0      1:0
# 26679       Eintracht Frankfurt       SC Freiburg             1:0      1:0
# 26658               Hannover 96     FC Schalke 04             2:1      2:1
# 26660               Hannover 96     FC Schalke 04             2:1      1:1
# 26663               Hannover 96     FC Schalke 04             2:1      0:1
# 26668                Hertha BSC  SV Werder Bremen             2:2      2:2
# 26670                Hertha BSC  SV Werder Bremen             2:2      2:1
# 26671                Hertha BSC  SV Werder Bremen             2:2      2:0
# 26673                Hertha BSC  SV Werder Bremen             2:2      1:0
# 26647         Borussia Dortmund  Bayer Leverkusen             0:2      0:2
# 26649         Borussia Dortmund  Bayer Leverkusen             0:2      0:1
# 26635           SC Paderborn 07   1. FSV Mainz 05             2:2      2:2
# 26636           SC Paderborn 07   1. FSV Mainz 05             2:2      2:1
# 26638           SC Paderborn 07   1. FSV Mainz 05             2:2      1:1
# 26641           SC Paderborn 07   1. FSV Mainz 05             2:2      0:1
# 26628  Borussia Mönchengladbach     VfB Stuttgart             1:1      1:1
#
#       goal_time_raw extratime_raw      League Spieltag     Saison
# 26683           52'            no  Bundesliga        1  2014/2015
# 26684           47'            no  Bundesliga        1  2014/2015
# 26685           38'            no  Bundesliga        1  2014/2015
# 26652           35'            no  Bundesliga        1  2014/2015
# 26654           33'            no  Bundesliga        1  2014/2015
# 26679           15'            no  Bundesliga        1  2014/2015
# 26658           70'            no  Bundesliga        1  2014/2015
# 26660           67'            no  Bundesliga        1  2014/2015
# 26663           47'            no  Bundesliga        1  2014/2015
# 26668           55'            no  Bundesliga        1  2014/2015
# 26670           53'            no  Bundesliga        1  2014/2015
# 26671           47'            no  Bundesliga        1  2014/2015
# 26673           16'            no  Bundesliga        1  2014/2015
# 26647           90'            no  Bundesliga        1  2014/2015
# 26649            1'            no  Bundesliga        1  2014/2015
# 26635           90'            no  Bundesliga        1  2014/2015
# 26636           87'            no  Bundesliga        1  2014/2015
# 26638           38'            no  Bundesliga        1  2014/2015
# 26641           34'            no  Bundesliga        1  2014/2015
# 26628           90'            no  Bundesliga        1  2014/2015

# %%
def remove_empty_goals(df):
    """
    Entfernt alle Einträge, bei denen 'goal_raw' leer ist.

    :param df: Der zu bearbeitende DataFrame.
    :return: Der bearbeitete DataFrame ohne leere 'goal_raw' Einträge.
    """
    # Entfernen von Zeilen, in denen 'goal_raw' leer ist
    df_cleaned = df.dropna(subset=['goal_raw'])
    return df_cleaned

# Anwenden der Funktion auf Ihren DataFrame
df_updated = remove_empty_goals(df_updated)
df_updated.head()

# %%
def rearrange_columns(df):
    """
    Entfernt die Spalte 'matchday_raw' und ändert die Reihenfolge der Spalten.

    :param df: Der zu bearbeitende DataFrame.
    :return: Der bearbeitete DataFrame mit der neuen Spaltenreihenfolge.
    """
    # Entfernen der Spalte 'matchday_raw'
    df = df.drop(columns=['matchday_raw'])

    # Festlegen der neuen Spaltenreihenfolge
    new_order = ['League', 'Saison', 'Spieltag', 'hometeam_raw', 'awayteam_raw',
                 'final_score_raw', 'goal_raw', 'goal_time_raw', 'extratime_raw']

    # Anordnen der Spalten in der neuen Reihenfolge
    df = df[new_order]
    return df

# Anwenden der Funktion auf Ihren DataFrame
df_ord = rearrange_columns(df_updated)
df_ord.head()

# %%
def save_to_excel(df, path="/Users/youri/VSC Data/Data Analytics/Bundesliga_Bereinigt.xlsx"):
    """
    Speichert den übergebenen DataFrame in einer Excel-Datei im angegebenen Verzeichnis.

    :param df: Der DataFrame, der gespeichert werden soll.
    :param path: Der vollständige Pfad und Name der zu erstellenden Excel-Datei.
    """
    try:
        # Speichern des DataFrame in einer Excel-Datei
        df.to_excel(path, index=False)
        return f"Datei '{path}' wurde erfolgreich gespeichert."
    except Exception as e:
        return f"Ein Fehler ist aufgetreten: {e}"

# Speichern des df_example DataFrame in einer Excel-Datei
save_to_excel(df_ord)
